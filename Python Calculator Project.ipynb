# %% [markdown]
# # My Python Calculator!!

# %% [raw]
#  Operations which we can perform:-
#  1)Addition
#  2)Substraction
#  3)Multiplication
#  4)Average
#  5)Square
#  6)Squareroot
#  7)Factorial

# %% [markdown]
# Enter '0'(zero) to terminate the inputs for Addition, Subtraction, Multiplication and Average

# %%
def addition ():                                      # Addition program
    print("Addition")
    n = float(input("Enter the number: "))            # User input
    t = 0  
    ans = 0
    while n != 0:
        ans = ans + n
        t+=1
        n = float(input("Enter another number (0 to calculate): "))
    return [ans,t]
def subtraction ():                                  # Substraction program
    print("Subtraction");
    n = float(input("Enter the number: "))           # User input
    t = 0  
    sum = 0
    while n != 0:
        ans = ans - n
        t+=1
        n = float(input("Enter another number (0 to calculate): "))
    return [ans,t]
def multiplication ():                               # Multiplication program
    print("Multiplication")
    n = float(input("Enter the number: "))           # User input
    t = 0                                           #  Total number enter
    ans = 1
    while n != 0:
        ans = ans * n
        t+=1
        n = float(input("Enter another number (0 to calculate): "))
    return [ans,t]
def average():                                      # Program to find average
    an = []
    an = addition()                                 # Linked to the addition program
    t = an[1]
    a = an[0]
    ans = a / t
    return [ans,t]
def square():                                       # Program to find square
    n = int(input("Enter the number: "))            # User input
    ans = n * n
    return [ans]
def squareroot():                                   # Program to find squareroot
    n = int(input("Enter the number: "))            # User input
    ans = n**0.5
    return [ans]
def factorial():                                   # Program to find factorial
    n = int(input("Enter the number: "))           # User input
    ans = 1
    for num in range(1,n+1):
        ans = ans*num
    return [ans]
    
while True:                                     # Driving program
    list = []
    print(" My python calculator!")
    print(" Enter 'add' for addition")
    print(" Enter 'sub' for substraction")
    print(" Enter 'mult' for multiplication")
    print(" Enter 'av' for average")
    print(" Enter 'sqr' for square")
    print(" Enter 'root' for square")
    print(" Enter 'fact' for square")
    print(" Enter 'q' for quit")
    c = input(" ")                              # To check which operation is selected by the user
    if c != 'q':
        if c == 'add':
            list = addition()
            print("Ans = ", list[0], " total inputs ",list[1])      # Output
        elif c == 'sub':
            list = subtraction()
            print("Ans = ", list[0], " total inputs ",list[1])      # Output
        elif c == 'mult':
            list = multiplication()
            print("Ans = ", list[0], " total inputs ",list[1])      # Output
        elif c == 'av':
            list = average()
            print("Ans = ", list[0], " total inputs ",list[1])      # Output
        elif c == 'sqr':
            list = square()
            print("Ans = ", list[0],)                               # Output
        elif c == 'root':
            list = squareroot()
            print("Ans = ", list[0],)                               # Output
        elif c == 'fact':
            list = factorial()
            print("Ans = ", list[0],)                               # Output
        else:
            print ("Sorry, invilid character")
    else:
        break
# Out:
#  My python calculator!
#  Enter 'add' for addition
#  Enter 'sub' for substraction
#  Enter 'mult' for multiplication
#  Enter 'av' for average
#  Enter 'sqr' for square
#  Enter 'root' for square
#  Enter 'fact' for square
#  Enter 'q' for quit
#  fact
# Enter the number: 5
# Ans =  120
#  My python calculator!
#  Enter 'add' for addition
#  Enter 'sub' for substraction
#  Enter 'mult' for multiplication
#  Enter 'av' for average
#  Enter 'sqr' for square
#  Enter 'root' for square
#  Enter 'fact' for square
#  Enter 'q' for quit
#  add
# Addition
# Enter the number: 50
# Enter another number (0 to calculate): 50
# Enter another number (0 to calculate): 0
# Ans =  100.0  total inputs  2
#  My python calculator!
#  Enter 'add' for addition
#  Enter 'sub' for substraction
#  Enter 'mult' for multiplication
#  Enter 'av' for average
#  Enter 'sqr' for square
#  Enter 'root' for square
#  Enter 'fact' for square
#  Enter 'q' for quit
#  q
